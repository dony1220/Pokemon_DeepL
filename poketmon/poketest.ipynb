# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/git_test"
# Out:
# /content/drive/MyDrive/Colab Notebooks/git_test

# %%
! git clone https://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@github.com/dony1220/dl.git #뒤는 깃 주소
# Out:
# Cloning into 'dl'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/git_test/dl/dl"
# Out:
# /content/drive/MyDrive/Colab Notebooks/git_test/dl/dl

# %%
# !git config --global user.email 'ehgus6158@hufs.ac.kr'
# !git config --global user.name 'dony1220'

# %%
! git add main.py

# %%
! git commit -m 'first_up'
# Out:
# [main 1097c91] first_up
#  1 file changed, 48 insertions(+)
#  create mode 100644 main.py

# %%
! git push
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 657 bytes | 164.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dony1220/dl.git
#    6421746..1097c91  main -> main
